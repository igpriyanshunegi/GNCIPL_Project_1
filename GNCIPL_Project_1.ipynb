# %% [markdown]
# # **Project Name**    - **Cyberattack Trends by Sector.**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# **Priyanshu**

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **Project Objective:**
#
# The goal of this project is to analyze publicly reported cyber incidents across multiple industries and develop a predictive machine learning framework that classifies attack vectors and identifies sector-specific risks. By detecting patterns in attack frequency and evolution over time, the project aims to help organizations strengthen defenses, prioritize resources, and enhance cyber resilience.
# ****
# **Context:**
#
# Cybersecurity incidents have become a major threat across industries such as finance, healthcare, government, retail, and energy. Breaches result in financial loss, reputational damage, regulatory penalties, and service disruption.
# By leveraging historical incident data from sources like PhishTank, CERT-In, Unit42, Kaggle, and Verizon DBIR reports, this project provides actionable intelligence on which sectors are most at risk, how attack trends have changed over years, and what attack vectors are most common.
# This intelligence supports policy-making, security investments, and proactive defense strategies.
# ****
# **Data Overview & Preprocessing:**
#
# The dataset(s) may include multiple fields such as:
#
# **Incident Details:** attack_type, vector, malware_family, severity
#
# **Categorical Variables:** industry_sector, country, organization_type
#
# **Time-based Columns:** detection_date, report_year, report_month
#
# **Impact Metrics:** records_exposed, downtime_hours, financial_loss
#
# **Target Variable:** Attack Vector (e.g., phishing, ransomware, misconfiguration, insider threat)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Cyberattacks have become increasingly frequent and sophisticated, targeting industries such as finance, healthcare, government, retail, and energy. Despite the availability of publicly reported incident data, organizations often struggle to extract actionable insights due to the unstructured, large-scale, and fragmented nature of cyber incident reports.
#
# Without a systematic approach to analyzing this data, businesses and policymakers face challenges in:
#
# Understanding which sectors are most frequently targeted
#
# Identifying the top attack vectors exploited by threat actors
#
# Detecting year-over-year trends in cyber incidents
#
# Allocating resources and budgets effectively to mitigate risks
#
# This gap limits the ability of organizations to make data-driven security decisions, leaving them vulnerable to evolving threats.

# %% [markdown]
# # What did you know about your dataset?

# %% [markdown]
# **File Name:** The dataset is stored in a file named Global_Cybersecurity_Threats_2015-2024.csv.
#
# **Timeframe:** The data covers a 10-year period, from 2015 to 2024.
#
# **Size:** The dataset contains 3000 entries, or rows.
#
# **Columns:** The dataset includes 10 columns providing various details about each cyber incident. These columns are:
#
# **Country:** The country where the incident occurred.
#
# **Year:** The year of the incident.
#
# **Attack Type:** The type of cyberattack.
#
# **Target Industry:** The industry sector that was targeted.
#
# **Financial Loss (in Million $):** The financial impact of the attack.
#
# **Number of Affected Users:** The number of individuals impacted.
#
# **Attack Source:** The origin of the attack (e.g., Hacker Group, Nation-state, Insider).
#
# **Security Vulnerability Type:** The vulnerability exploited during the attack.
#
# **Defense Mechanism Used:** The defense used to combat the attack.
#
# **Incident Resolution Time (in Hours):** The time it took to resolve the incident.

# %% [markdown]
# # **GitHub Link**

# %% [markdown]
# [GitHub Link here.](https://github.com/igpriyanshunegi/GNCIPL_Project_1)

# %% [markdown]
# # ***Data Analysis Start***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df = pd.read_csv('Global_Cybersecurity_Threats_2015-2024.csv')
print("\nDataset Information: ")
print(df.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              3000 non-null   object
#  1   Year                                 3000 non-null   int64
#  2   Attack Type                          3000 non-null   object
#  3   Target Industry                      3000 non-null   object
#  4   Financial Loss (in Million $)        3000 non-null   float64
#  5   Number of Affected Users             3000 non-null   int64
#  6   Attack Source                        3000 non-null   object
#  7   Security Vulnerability Type          3000 non-null   object
#  8   Defense Mechanism Used               3000 non-null   object
#  9   Incident Resolution Time (in Hours)  3000 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# ...

# %% [markdown]
# ### Description about Dataset

# %%
# Dataset Describe
print("\nDescription of the Dataset:")
print(df.describe())
# Out:
# Description of the Dataset:
#               Year  Financial Loss (in Million $)  Number of Affected Users  \
# count  3000.000000                    3000.000000               3000.000000
# mean   2019.570333                      50.492970             504684.136333
# std       2.857932                      28.791415             289944.084972
# min    2015.000000                       0.500000                424.000000
# 25%    2017.000000                      25.757500             255805.250000
# 50%    2020.000000                      50.795000             504513.000000
# 75%    2022.000000                      75.630000             758088.500000
# max    2024.000000                      99.990000             999635.000000
#
#        Incident Resolution Time (in Hours)
# count                          3000.000000
# mean                             36.476000
# std                              20.570768
# min                               1.000000
# ...

# %% [markdown]
# ### Information about columns

# %%
# Dataset Columns
print("\nColumns Present in the Dataset:")
print(df.columns)

print("\n Data types of the columns of the dataset: ")
print(df.dtypes)
# Out:
# Columns Present in the Dataset:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')
#
#  Data types of the columns of the dataset:
# Country                                 object
# Year                                     int64
# Attack Type                             object
# Target Industry                         object
# Financial Loss (in Million $)          float64
# Number of Affected Users                 int64
# Attack Source                           object
# Security Vulnerability Type             object
# Defense Mechanism Used                  object
# Incident Resolution Time (in Hours)      int64
# dtype: object

# %% [markdown]
# ### Total number of incident

# %%
print("\nTotal number of incidents:", len(df))
# Out:
# Total number of incidents: 3000

# %% [markdown]
# ### Number of Rows & Columns

# %%
# Dataset Rows & Columns count
print("\nNumber of Rows:", df.shape[0])
print("\nNumber of Columns:", df.shape[1])
# Out:
# Number of Rows: 3000
# Number of Columns: 10

# %% [markdown]
# ### Incident by year

# %%
print("\nIncidents by year:")
print(df['Year'].value_counts().sort_index())
# Out:
# Incidents by year:
# Year
# 2015    277
# 2016    285
# 2017    319
# 2018    310
# 2019    263
# 2020    315
# 2021    299
# 2022    318
# 2023    315
# 2024    299
# Name: count, dtype: int64

# %% [markdown]
# ### Reading Dataset

# %%
#Reading the CVS file
print("\n",df)
# Out:
#       Country  Year        Attack Type     Target Industry  \
# 0       China  2019           Phishing           Education
# 1       China  2019         Ransomware              Retail
# 2       India  2017  Man-in-the-Middle                  IT
# 3          UK  2024         Ransomware  Telecommunications
# 4     Germany  2018  Man-in-the-Middle                  IT
# ...       ...   ...                ...                 ...
# 2995       UK  2021         Ransomware          Government
# 2996   Brazil  2023      SQL Injection  Telecommunications
# 2997   Brazil  2017      SQL Injection                  IT
# 2998       UK  2022      SQL Injection                  IT
# 2999  Germany  2021      SQL Injection              Retail
#
#       Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                             80.53                    773169  Hacker Group
# 1                             62.19                    295961  Hacker Group
# ...

# %% [markdown]
# ### Top 5 data

# %%
# Dataset First Look
print("\nFirst 5 Rows of the Dataset:")
print(df.head())
# Out:
# First 5 Rows of the Dataset:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# ...

# %% [markdown]
# ### Top 7  most targeted industries

# %%
("\nTop 7 most targeted industries:")
print(df['Target Industry'].value_counts().head(7))
# Out:
# Target Industry
# IT                    478
# Banking               445
# Healthcare            429
# Retail                423
# Education             419
# Government            403
# Telecommunications    403
# Name: count, dtype: int64

# %% [markdown]
# ### Top 6 attack types

# %%
print("\nTop 6 attack types:")
print(df['Attack Type'].value_counts().head(6))
# Out:
# Top 6 attack types:
# Attack Type
# DDoS                 531
# Phishing             529
# SQL Injection        503
# Ransomware           493
# Malware              485
# Man-in-the-Middle    459
# Name: count, dtype: int64

# %% [markdown]
# ### Average financial loss by attack type (in Million $)

# %%
print("\nAverage financial loss by attack type (in Million $):")
print(df.groupby('Attack Type')['Financial Loss (in Million $)'].mean().sort_values(ascending=False))
# Out:
# Average financial loss by attack type (in Million $):
# Attack Type
# DDoS                 52.035631
# Man-in-the-Middle    51.309085
# Phishing             50.459905
# SQL Injection        50.013042
# Ransomware           49.653793
# Malware              49.418454
# Name: Financial Loss (in Million $), dtype: float64

# %% [markdown]
# ### Most common attack sources

# %%
print("\nMost common attack sources:")
print(df['Attack Source'].value_counts())
# Out:
# Most common attack sources:
# Attack Source
# Nation-state    794
# Unknown         768
# Insider         752
# Hacker Group    686
# Name: count, dtype: int64

# %% [markdown]
# ### Number of Duplicate Values

# %%
# Dataset Duplicate Value Count
print("\nNumber of Duplicate Values:", df.duplicated().sum())
# Out:
# Number of Duplicate Values: 0

# %% [markdown]
# ### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("\nMissing Values in each Columns of the Dataset: ")
print(df.isnull().sum())
# Out:
# Missing Values in each Columns of the Dataset:
# Country                                0
# Year                                   0
# Attack Type                            0
# Target Industry                        0
# Financial Loss (in Million $)          0
# Number of Affected Users               0
# Attack Source                          0
# Security Vulnerability Type            0
# Defense Mechanism Used                 0
# Incident Resolution Time (in Hours)    0
# dtype: int64

# %% [markdown]
# ### Check Unique Values for each columns

# %%
# Check Unique Values for each columns
print("\nUnique Values in each Columns of the Dataset: ")
print(df.nunique())
# Out:
# Unique Values in each Columns of the Dataset:
# Country                                  10
# Year                                     10
# Attack Type                               6
# Target Industry                           7
# Financial Loss (in Million $)          2536
# Number of Affected Users               2998
# Attack Source                             4
# Security Vulnerability Type               4
# Defense Mechanism Used                    5
# Incident Resolution Time (in Hours)      72
# dtype: int64

# %% [markdown]
# ## ***Analyze attack vectors***

# %% [markdown]
# #### Chart - Top 6 attack vectors

# %%
# Get top 6 attack vectors
top_vectors = df['Attack Type'].value_counts().head(6)

# Plot bar chart for top attack vectors
plt.figure(figsize=(12, 6))
top_vectors.plot(kind='bar')
plt.title('Top 6 Attack Types')
plt.xlabel('Attack Type')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #####  What are the insight found from the chart?

# %% [markdown]
# **From the bar chart showing the top 6 attack types, we can identify several key insights:**
#
# **Distribution of Attack Types:**
#
# The chart displays the frequency distribution of different cyber attack methods
# Shows which attack vectors are most commonly used by threat actors
#
# **Common Attack Vectors:**
#
# 1. DDoS (Distributed Denial of Service) appears to be one of the most frequent attack types
# 2. Phishing is also among the top attack methods
# 3. Man-in-the-Middle attacks show significant presence
# 4. SQL Injection and Ransomware are also prominent threats
#
#
# **Strategic Implications:**
#
# Organizations should prioritize defenses against the most common attack types
# Security resources and training should focus on preventing/mitigating these top threats
# Incident response plans should be particularly robust for these attack vectors

# %% [markdown]
# #### Chart - Year-wise analysis of top 6 attack vectors

# %%
# Create a year-wise analysis of top 6 attack vectors
top_5_vectors = df['Attack Type'].value_counts().head(6).index
vector_by_year = df[df['Attack Type'].isin(top_5_vectors)].pivot_table(
index='Year',
columns='Attack Type',
aggfunc='size',
fill_value=0)

# Plot line chart for top 6 attack vectors over time
plt.figure(figsize=(12, 6))
vector_by_year.plot(marker='o')
plt.title('Top 6 Attack Types Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #####  What are the insight found from the chart?

# %% [markdown]
# 1. **Ransomware and Malware are the most frequent attack types:**
#
# The number of incidents for Ransomware and Malware has been consistently higher than the other three attack types throughout the observed period from 2015 to 2024.
#
# 2. **Ransomware and Phishing are on the rise:**
#
# Ransomware incidents exhibit a sharp upward trend, especially from 2021 onwards. Similarly, the number of Phishing incidents has been gradually increasing over the years.
#
# 3. **SQL Injection and DDoS attacks have declined:**
#
# The number of incidents for both SQL Injection and DDoS attacks has seen a significant decrease over time.
#
# 4. **Fluctuating trends:**
#
# While Malware incidents show significant year-to-year fluctuations, they remain a prevalent threat.

# %% [markdown]
# ## ***Analyze attacks by sector and year***

# %% [markdown]
# #### Chart - Attack according to sector and year

# %%
# Create a pivot table for sector and year
attacks_by_sector_year = pd.crosstab(df['Target Industry'], df['Year'])

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(attacks_by_sector_year, cmap='YlOrRd', annot=True, fmt='d')
plt.title('Frequency of Cyber Attacks by Sector and Year')
plt.xlabel('Year')
plt.ylabel('Target Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### What are the insight found from the chart?

# %% [markdown]
# **IT Sector is consistently targeted:**
#
#  The IT industry has been a frequent target of attacks throughout the entire period from 2015 to 2024, with high numbers of incidents in most years.
#
# **Education Sector shows a high spike in 2018:**
#
#  The number of cyberattacks on the Education sector peaked significantly in 2018, with 59 incidents, which is notably higher than other years for this sector.
#
# **Government Sector has a relatively stable but high number of attacks:**
#
#  The Government sector experiences a consistent and high volume of attacks each year, with the number of incidents remaining in a narrow range.
#
# **Healthcare and Retail Sectors show a general upward trend:**
#
#  While there are year-to-year fluctuations, both the Healthcare and Retail sectors show a gradual increase in the number of cyberattacks over the years, with a notable peak for Healthcare in 2017.
#
# **Banking and Telecommunications sectors have fluctuating attack frequencies:**
#
#  The number of attacks in the Banking and Telecommunications sectors varies from year to year, with no clear long-term trend.

# %% [markdown]
# #### Chart - Total attacks by sector

# %%
# Get total attacks by sector
total_by_sector = df['Target Industry'].value_counts()

# Plot bar chart for total attacks by sector
plt.figure(figsize=(12, 6))
total_by_sector.plot(kind='bar')
plt.title('Total Cyber Attacks by Industry Sector')
plt.xlabel('Target Industry')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### What are the insight found from the chart?

# %% [markdown]
# **IT Sector is the most targeted:**
#
#  The IT sector has the highest number of reported attacks with a total of 478 incidents.
#
# **Banking and Healthcare sectors are the next most targeted:**
#
#  Following the IT sector, the Banking and Healthcare sectors are also high-frequency targets with 445 and 429 incidents, respectively.
#
# **Retail and Education are close behind:**
#
#  The Retail and Education sectors experienced a high number of attacks, with 423 and 419 incidents each.
#
# **Government and Telecommunications have the lowest number of attacks among the top sectors:**
#
#  The Government and Telecommunications sectors have the lowest number of attacks among the sectors analyzed, both with 403 incidents.

# %% [markdown]
# # **Thank You**
